# %%
import pandas as pd
import requests

# Fetch the data.
df = pd.read_csv("https://ourworldindata.org/grapher/life-expectancy.csv?v=1&csvType=full&useColumnShortNames=true", storage_options = {'User-Agent': 'Our World In Data data fetch/1.0'})

# Fetch the metadata
metadata = requests.get("https://ourworldindata.org/grapher/life-expectancy.metadata.json?v=1&csvType=full&useColumnShortNames=true").json()

# %%
df.head(3)
# Out:
#         entity code  year  life_expectancy_0
# 0  Afghanistan  AFG  1950            28.1563
# 1  Afghanistan  AFG  1951            28.5836
# 2  Afghanistan  AFG  1952            29.0138

# %%
df.columns.tolist()
# Out:
# ['entity', 'code', 'year', 'life_expectancy_0']

# %%
df.describe()
# Out:
#                year  life_expectancy_0
# count  21565.000000       21565.000000
# mean    1976.992812          61.942232
# std       38.461606          12.925912
# min     1543.000000          10.989100
# 25%     1962.000000          52.703000
# 50%     1982.000000          64.479900
# 75%     2003.000000          71.978900
# max     2023.000000          86.372400

# %%
#Cual era la ezperanza de vida en 1970 de todos los paises?
df[df["year"] == 1970][["entity", "life_expectancy_0"]]
# Out:
#                entity  life_expectancy_0
# 20        Afghanistan            37.4601
# 96             Africa            44.9859
# 170           Albania            65.2343
# 247           Algeria            43.3280
# 321    American Samoa            66.3642
# ...               ...                ...
# 21208  Western Sahara            42.6617
# 21289           World            56.2664
# 21363           Yemen            40.5729
# 21437          Zambia            53.4039
# 21511        Zimbabwe            57.7608
#
# [261 rows x 2 columns]

# %%
df[df["entity"].str.contains("Mexico", regex=True)]
# Out:
#        entity code  year  life_expectancy_0
# 12372  Mexico  MEX  1893            23.2900
# 12373  Mexico  MEX  1894            26.6200
# 12374  Mexico  MEX  1895            29.5200
# 12375  Mexico  MEX  1896            28.8000
# 12376  Mexico  MEX  1897            26.2400
# ...       ...  ...   ...                ...
# 12488  Mexico  MEX  2019            74.5302
# 12489  Mexico  MEX  2020            70.4492
# 12490  Mexico  MEX  2021            69.7499
# 12491  Mexico  MEX  2022            73.9731
# 12492  Mexico  MEX  2023            75.0690
#
# [121 rows x 4 columns]

# %%
df.columns.to_list()
# Out:
# ['entity', 'code', 'year', 'life_expectancy_0']

# %%
df.rename(columns = {"entity": "Pais"}, inplace = True)

# %%
df.head()
# Out:
#           Pais code  year  life_expectancy_0
# 0  Afghanistan  AFG  1950            28.1563
# 1  Afghanistan  AFG  1951            28.5836
# 2  Afghanistan  AFG  1952            29.0138
# 3  Afghanistan  AFG  1953            29.4521
# 4  Afghanistan  AFG  1954            29.6975

# %%
df.set_index("Pais")
# Out:
#             code  year  life_expectancy_0
# Pais
# Afghanistan  AFG  1950            28.1563
# Afghanistan  AFG  1951            28.5836
# Afghanistan  AFG  1952            29.0138
# Afghanistan  AFG  1953            29.4521
# Afghanistan  AFG  1954            29.6975
# ...          ...   ...                ...
# Zimbabwe     ZWE  2019            61.0603
# Zimbabwe     ZWE  2020            61.5300
# Zimbabwe     ZWE  2021            60.1347
# Zimbabwe     ZWE  2022            62.3601
# Zimbabwe     ZWE  2023            62.7748
#
# [21565 rows x 3 columns]

# %%
df.loc[df["code"].isnull()]
# Out:
#                                         Pais code  year  life_expectancy_0
# 375                                 Americas  NaN  1770            34.8000
# 376                                 Americas  NaN  1830            34.8000
# 377                                 Americas  NaN  1850            35.1000
# 378                                 Americas  NaN  1870            35.1000
# 379                                 Americas  NaN  1900            41.0000
# ...                                      ...  ...   ...                ...
# 17703  Small Island Developing States (SIDS)  NaN  2019            72.0847
# 17704  Small Island Developing States (SIDS)  NaN  2020            71.7761
# 17705  Small Island Developing States (SIDS)  NaN  2021            69.8938
# 17706  Small Island Developing States (SIDS)  NaN  2022            72.1257
# 17707  Small Island Developing States (SIDS)  NaN  2023            72.7255
#
# [1348 rows x 4 columns]

# %%
df.set_index(["code","year"])
# Out:
#                   Pais  life_expectancy_0
# code year
# AFG  1950  Afghanistan            28.1563
#      1951  Afghanistan            28.5836
#      1952  Afghanistan            29.0138
#      1953  Afghanistan            29.4521
#      1954  Afghanistan            29.6975
# ...                ...                ...
# ZWE  2019     Zimbabwe            61.0603
#      2020     Zimbabwe            61.5300
#      2021     Zimbabwe            60.1347
#      2022     Zimbabwe            62.3601
#      2023     Zimbabwe            62.7748
#
# [21565 rows x 2 columns]

# %%
df.set_index("Pais", inplace = True)

# %%
df.loc[df["code"].isnull()]
# Out:
#                                       code  year  life_expectancy_0
# Pais
# Americas                               NaN  1770            34.8000
# Americas                               NaN  1830            34.8000
# Americas                               NaN  1850            35.1000
# Americas                               NaN  1870            35.1000
# Americas                               NaN  1900            41.0000
# ...                                    ...   ...                ...
# Small Island Developing States (SIDS)  NaN  2019            72.0847
# Small Island Developing States (SIDS)  NaN  2020            71.7761
# Small Island Developing States (SIDS)  NaN  2021            69.8938
# Small Island Developing States (SIDS)  NaN  2022            72.1257
# Small Island Developing States (SIDS)  NaN  2023            72.7255
#
# [1348 rows x 3 columns]

# %%
df.loc[df["code"].notnull(),["entity","year","life_expectancy_0"]].head(3)
# Out:
#         entity  year  life_expectancy_0
# 0  Afghanistan  1950            28.1563
# 1  Afghanistan  1951            28.5836
# 2  Afghanistan  1952            29.0138

# %%
df.dropna(subset = ["code"], inplace = True)
df.isnull().sum()
# Out:
# entity               0
# code                 0
# year                 0
# life_expectancy_0    0
# dtype: int64

# %%
df.shape
# Out:
# (20217, 4)

# %%
df.rename(columns={"entity": "Pais"})
# Out:
#               Pais code  year  life_expectancy_0
# 0      Afghanistan  AFG  1950            28.1563
# 1      Afghanistan  AFG  1951            28.5836
# 2      Afghanistan  AFG  1952            29.0138
# 3      Afghanistan  AFG  1953            29.4521
# 4      Afghanistan  AFG  1954            29.6975
# ...            ...  ...   ...                ...
# 21560     Zimbabwe  ZWE  2019            61.0603
# 21561     Zimbabwe  ZWE  2020            61.5300
# 21562     Zimbabwe  ZWE  2021            60.1347
# 21563     Zimbabwe  ZWE  2022            62.3601
# 21564     Zimbabwe  ZWE  2023            62.7748
#
# [20217 rows x 4 columns]

# %%
resultado = (
    df.groupby("entity")["life_expectancy_0"]
    .mean()
    .sort_values(ascending = True)
)
resultado.head(10)
# Out:
# entity
# USSR                        32.700000
# South Sudan                 37.841631
# Sierra Leone                43.189605
# Mali                        43.760793
# Niger                       44.187513
# East Timor                  44.684692
# Nigeria                     44.855897
# Chad                        45.007786
# Central African Republic    45.084431
# Malawi                      45.554985
# Name: life_expectancy_0, dtype: float64

# %%
#1970 a adelante esperanza de vida promedio por pais
df[df["year"] >= 1970].groupby("entity")["life_expectancy_0"].mean().sort_values(ascending = True).head(10)
# Out:
# entity
# South Sudan                 41.076146
# Central African Republic    47.109006
# Sierra Leone                47.234867
# Chad                        47.391891
# Niger                       47.716867
# Nigeria                     47.721319
# Mali                        48.654591
# Somalia                     48.799163
# Angola                      49.022959
# East Timor                  49.192574
# Name: life_expectancy_0, dtype: float64

# %%
resultado = (
    df.groupby("entity")["life_expectancy_0"]
    .mean()
    .sort_values(ascending=True)
)
resultado.head(10)
# Out:
# entity
# USSR                        32.700000
# South Sudan                 37.841631
# Sierra Leone                43.189605
# Mali                        43.760793
# Niger                       44.187513
# East Timor                  44.684692
# Nigeria                     44.855897
# Chad                        45.007786
# Central African Republic    45.084431
# Malawi                      45.554985
# Name: life_expectancy_0, dtype: float64

# %%
df_1970_2023 = df[(df["year"]>=1970)]
resultado = (
    df_1970_2023.groupby("entity")["life_expectancy_0"]
    .mean()
    .sort_values(ascending=True)
)
resultado.head(10)
# Out:
# entity
# South Sudan                 41.076146
# Central African Republic    47.109006
# Sierra Leone                47.234867
# Chad                        47.391891
# Niger                       47.716867
# Nigeria                     47.721319
# Mali                        48.654591
# Somalia                     48.799163
# Angola                      49.022959
# East Timor                  49.192574
# Name: life_expectancy_0, dtype: float64

# %%
df_1909_1930 = df[(df["year"]>=1909) & (df["year"]<=1930)]
df_1909_1930[df_1909_1930["entity"].str.contains("Mex", regex=True)]
# Out:
#        entity code  year  life_expectancy_0
# 12388  Mexico  MEX  1909              29.21
# 12389  Mexico  MEX  1910              28.00
# 12390  Mexico  MEX  1920              34.00
# 12391  Mexico  MEX  1922              32.60
# 12392  Mexico  MEX  1923              33.50
# 12393  Mexico  MEX  1924              32.80
# 12394  Mexico  MEX  1925              32.10
# 12395  Mexico  MEX  1926              34.20
# 12396  Mexico  MEX  1927              40.30
# 12397  Mexico  MEX  1928              34.50
# 12398  Mexico  MEX  1929              35.40
# 12399  Mexico  MEX  1930              34.00
