# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# Paulina González Ramírez 81678 Práctica 1.1

# %%
df = pd.read_csv('../data/raw/annual-population-growth/annual-population-growth.csv')

# %%
df.head()
# Out:
#         Entity Code  Year  Annual change in population  \
# 0  Afghanistan  AFG  1951                     103163.0
# 1  Afghanistan  AFG  1952                     108441.0
# 2  Afghanistan  AFG  1953                     108919.0
# 3  Afghanistan  AFG  1954                     111251.0
# 4  Afghanistan  AFG  1955                     119027.0
#
#    Annual population change (Projected)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN

# %%
df.shape
# Out:
# (38400, 5)

# %% [markdown]
# 1.	¿Cuántas filas y columnas tiene el dataset?
# 38400 filas y 5 columnas

# %%
df.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Annual change in population',
#        'Annual population change (Projected)'],
#       dtype='str')

# %%
df.columns.tolist()
# Out:
# ['Entity',
#  'Code',
#  'Year',
#  'Annual change in population',
#  'Annual population change (Projected)']

# %%
df.dtypes
# Out:
# Entity                                      str
# Code                                        str
# Year                                      int64
# Annual change in population             float64
# Annual population change (Projected)    float64
# dtype: object

# %% [markdown]
# 2.	¿Qué tipo de datos contiene la variable Year?
# entero, int 64

# %%
df.describe()
# Out:
#                Year  Annual change in population  \
# count  38400.000000                 1.868800e+04
# mean    2025.500000                 2.063019e+06
# std       43.300872                 9.440859e+06
# min     1951.000000                -3.315935e+06
# 25%     1988.000000                 1.781000e+03
# 50%     2025.500000                 4.689800e+04
# 75%     2063.000000                 3.021128e+05
# max     2100.000000                 9.337137e+07
#
#        Annual population change (Projected)
# count                          1.971200e+04
# mean                           8.375481e+05
# std                            5.816745e+06
# min                           -2.291035e+07
# 25%                           -9.742750e+03
# 50%                            9.350000e+01
# 75%                            1.411160e+05
# max                            7.206736e+07

# %%
df.isnull().sum()
# Out:
# Entity                                      0
# Code                                     1200
# Year                                        0
# Annual change in population             19712
# Annual population change (Projected)    18688
# dtype: int64

# %% [markdown]
# 3.	¿Existen valores faltantes?
# si entity y year

# %%
df["Entity"].nunique()
# Out:
# 256

# %% [markdown]
# 4.	¿Cuántas entidades diferentes contiene el dataset? 256

# %%
anio_consultado= 2020

# %%
print("año consultado:", anio_consultado)
# Out:
# año consultado: 2020

# %%
df_anio_consultado = df[df["Year"]==anio_consultado & (df["Entity"]!="Venezuela")]
df_anio_consultado.head()
# Out:
# Empty DataFrame
# Columns: [Entity, Code, Year, Annual change in population, Annual population change (Projected)]
# Index: []

# %%
df_anio_consultado.mean(numeric_only=True)
# Out:
# Year                                   NaN
# Annual change in population            NaN
# Annual population change (Projected)   NaN
# dtype: float64

# %%
df_anio_consultado.shape
# Out:
# (0, 5)

# %%
df.head(3)
# Out:
#         Entity Code  Year  Annual change in population  \
# 0  Afghanistan  AFG  1951                     103163.0
# 1  Afghanistan  AFG  1952                     108441.0
# 2  Afghanistan  AFG  1953                     108919.0
#
#    Annual population change (Projected)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN

# %%
df_year=df[["Entity","Year"]]
df_year.head()
# Out:
#         Entity  Year
# 0  Afghanistan  1951
# 1  Afghanistan  1952
# 2  Afghanistan  1953
# 3  Afghanistan  1954
# 4  Afghanistan  1955

# %%
df_extraccion_filas = df[df["Year"] == 2020]
df_extraccion_filas.head()
# Out:
#              Entity    Code  Year  Annual change in population  \
# 69      Afghanistan     AFG  2020                    1212852.0
# 219     Africa (UN)  UN_AFR  2020                   32815675.0
# 369         Albania     ALB  2020                     -13061.0
# 519         Algeria     DZA  2020                     747543.0
# 669  American Samoa     ASM  2020                       -451.0
#
#      Annual population change (Projected)
# 69                                    NaN
# 219                                   NaN
# 369                                   NaN
# 519                                   NaN
# 669                                   NaN

# %%
df_2020_mex = df [(df["Year"] == 2020) & (df["Code"] == "MEX")]
df_2020_mex.head()
# Out:
#        Entity Code  Year  Annual change in population  \
# 22269  Mexico  MEX  2020                    1036075.0
#
#        Annual population change (Projected)
# 22269                                   NaN

# %%
#Rango de fechas desdeñaño que nacimos hasta el 2020
df_2005_2020_mex = df [(df["Year"] >= 2005) & (df["Year"] <= 2020) & (df["Code"] == "MEX")]
df_2005_2020_mex.head()
# Out:
#        Entity Code  Year  Annual change in population  \
# 22254  Mexico  MEX  2005                    1417373.0
# 22255  Mexico  MEX  2006                    1442162.0
# 22256  Mexico  MEX  2007                    1520690.0
# 22257  Mexico  MEX  2008                    1599930.0
# 22258  Mexico  MEX  2009                    1625434.0
#
#        Annual population change (Projected)
# 22254                                   NaN
# 22255                                   NaN
# 22256                                   NaN
# 22257                                   NaN
# 22258                                   NaN

# %%
df_ext_EYA = df_2005_2020_mex[["Entity","Year","Annual change in population"]]
df_ext_EYA.head()
# Out:
#        Entity  Year  Annual change in population
# 22254  Mexico  2005                    1417373.0
# 22255  Mexico  2006                    1442162.0
# 22256  Mexico  2007                    1520690.0
# 22257  Mexico  2008                    1599930.0
# 22258  Mexico  2009                    1625434.0

# %%
#Promedio del rango esntre el 2005 y 2020 en México de personas 
df_ext_EYA.mean(numeric_only=True)
# Out:
# Year                              2012.500
# Annual change in population    1400307.625
# dtype: float64

# %%
df.loc[:,["Entity", "Year"]]
# Out:
#             Entity  Year
# 0      Afghanistan  1951
# 1      Afghanistan  1952
# 2      Afghanistan  1953
# 3      Afghanistan  1954
# 4      Afghanistan  1955
# ...            ...   ...
# 38395     Zimbabwe  2096
# 38396     Zimbabwe  2097
# 38397     Zimbabwe  2098
# 38398     Zimbabwe  2099
# 38399     Zimbabwe  2100
#
# [38400 rows x 2 columns]

# %%
df.iloc[:,0:2]
# Out:
#             Entity Code
# 0      Afghanistan  AFG
# 1      Afghanistan  AFG
# 2      Afghanistan  AFG
# 3      Afghanistan  AFG
# 4      Afghanistan  AFG
# ...            ...  ...
# 38395     Zimbabwe  ZWE
# 38396     Zimbabwe  ZWE
# 38397     Zimbabwe  ZWE
# 38398     Zimbabwe  ZWE
# 38399     Zimbabwe  ZWE
#
# [38400 rows x 2 columns]

# %%
df.iloc[30:35,0:12]
# Out:
#          Entity Code  Year  Annual change in population  \
# 30  Afghanistan  AFG  1981                   -1231727.0
# 31  Afghanistan  AFG  1982                    -946206.0
# 32  Afghanistan  AFG  1983                     -73395.0
# 33  Afghanistan  AFG  1984                     272237.0
# 34  Afghanistan  AFG  1985                     236633.0
#
#     Annual population change (Projected)
# 30                                   NaN
# 31                                   NaN
# 32                                   NaN
# 33                                   NaN
# 34                                   NaN

# %%
df.iloc[10000]
# Out:
# Entity                                  Equatorial Guinea
# Code                                                  GNQ
# Year                                                 2051
# Annual change in population                           NaN
# Annual population change (Projected)              46407.0
# Name: 10000, dtype: object

# %%
#ej2
df.loc[:,["Entity", "Year", "Annual change in population"]]
# Out:
#             Entity  Year  Annual change in population
# 0      Afghanistan  1951                     103163.0
# 1      Afghanistan  1952                     108441.0
# 2      Afghanistan  1953                     108919.0
# 3      Afghanistan  1954                     111251.0
# 4      Afghanistan  1955                     119027.0
# ...            ...   ...                          ...
# 38395     Zimbabwe  2096                          NaN
# 38396     Zimbabwe  2097                          NaN
# 38397     Zimbabwe  2098                          NaN
# 38398     Zimbabwe  2099                          NaN
# 38399     Zimbabwe  2100                          NaN
#
# [38400 rows x 3 columns]

# %%
#ej3
df.loc[10000,["Entity","Year","Annual change in population"]]
# Out:
# Entity                         Equatorial Guinea
# Year                                        2051
# Annual change in population                  NaN
# Name: 10000, dtype: object

# %%
#ej4
df.loc[(df["Year"] == 2020) & (df["Entity"] == "Mexico")]
# Out:
#        Entity Code  Year  Annual change in population  \
# 22269  Mexico  MEX  2020                    1036075.0
#
#        Annual population change (Projected)
# 22269                                   NaN

# %%
#ej5
df.iloc[:5]
# Out:
#         Entity Code  Year  Annual change in population  \
# 0  Afghanistan  AFG  1951                     103163.0
# 1  Afghanistan  AFG  1952                     108441.0
# 2  Afghanistan  AFG  1953                     108919.0
# 3  Afghanistan  AFG  1954                     111251.0
# 4  Afghanistan  AFG  1955                     119027.0
#
#    Annual population change (Projected)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN

# %%
#ej6
df.iloc[["0","2","3"]]
# Out:
#         Entity Code  Year  Annual change in population  \
# 0  Afghanistan  AFG  1951                     103163.0
# 2  Afghanistan  AFG  1953                     108919.0
# 3  Afghanistan  AFG  1954                     111251.0
#
#    Annual population change (Projected)
# 0                                   NaN
# 2                                   NaN
# 3                                   NaN

# %%
#ej7
df.iloc[0:4,0:4]
# Out:
#         Entity Code  Year  Annual change in population
# 0  Afghanistan  AFG  1951                     103163.0
# 1  Afghanistan  AFG  1952                     108441.0
# 2  Afghanistan  AFG  1953                     108919.0
# 3  Afghanistan  AFG  1954                     111251.0

# %%
#ejercicio con año de nacimiento e inicial de mi apellido en un país
df_filtrado=df[(df["Year"]>= 2005) &(df["Year"]<=2023) & (df["Entity"] == "Equatorial Guinea")][["Annual change in population"]]
df_filtrado.head()
# Out:
#       Annual change in population
# 9954                      47446.0
# 9955                      42979.0
# 9956                      45704.0
# 9957                      48485.0
# 9958                      51145.0

# %%
print(df_filtrado.mean())
# Out:
# Annual change in population    49875.368421
# dtype: float64

# %%
print(df_filtrado.median())
# Out:
# Annual change in population    51642.0
# dtype: float64

# %%
print(df_filtrado.var())
# Out:
# Annual change in population    1.884482e+07
# dtype: float64

# %%
print(df_filtrado.std())
# Out:
# Annual change in population    4341.06165
# dtype: float64

# %%
print(df_filtrado.min())
# Out:
# Annual change in population    42317.0
# dtype: float64

# %%
print(df_filtrado.max())
# Out:
# Annual change in population    54267.0
# dtype: float64

# %% [markdown]
# Preguntas actividad 3:
# 1.	¿Cuál es el valor de la media?
# 49875.368421
# 2.	¿Cuál es el valor de la mediana?
#  51642.0
# 3.	¿Cuál es el valor de la desviación estándar?
# 4341.06165
# 4.	¿Qué entidad presenta el valor mínimo y cuál el máximo?
# 42317.0 y 54267.0

# %%
import sys

print("Python:", sys.version)
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
# Out:
# Python: 3.14.6 (tags/v3.14.6:c63aec6, Jun 10 2026, 10:26:10) [MSC v.1944 64 bit (AMD64)]
# Pandas: 3.0.5
# NumPy: 2.5.2

# %% [markdown]
# prueba de git jiji
